# %%
import pandas as pd

df = pd.read_csv("combined.csv")

# %%
import matplotlib.pyplot as plt

plt.plot(df["real estate"])

# %%
df
# Out:
#      Unnamed: 0  automotive industry  auto insurance  second hand car  \
# 0    2006-01-01            58.000000        0.000000        76.000000
# 1    2006-01-08            38.000000        0.000000        57.000000
# 2    2006-01-15            55.000000        0.000000        69.000000
# 3    2006-01-22            59.000000       64.000000        66.000000
# 4    2006-01-29             0.000000        0.000000        89.000000
# ..          ...                  ...             ...              ...
# 674  2018-12-02            13.291959       34.452026        50.757361
# 675  2018-12-09             7.753643        3.445203        51.482466
# 676  2018-12-16             0.000000       20.326695        51.482466
# 677  2018-12-23             0.000000        0.000000        65.984570
# 678  2018-12-30            19.661023        0.000000        59.458623
#
#      mobile phone  mercedes benz  electrical appliance        wifi  \
# ...
